# %% [markdown]
# ![Screenshot 2025-02-09 at 17.57.07.png](<attachment:Screenshot 2025-02-09 at 17.57.07.png>)

# %%
# Given
n = int(input())
arr = map(int, input().split())

# TODO solution
lst = []
for x in arr:
    lst.append(x) # getting a list

new = sorted(lst, reverse=True)
highest = -100
for x in range(0, len(new)):
    if new[x] in new[x+1:]: # 6 in 6532 -- 6
        pass
    else:
        if new[x] > highest:
            highest = new[x]
        else:
            print(new[x])
            break
# Out:
# 6

# %%
# FIX BETTER SOLUTION
# Given
n = int(input())
arr = map(int, input().split())

# TODO 
scores = list(arr)
unique_scores = sorted(set(scores))
